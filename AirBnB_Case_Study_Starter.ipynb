# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidence to answer the following questions.
#
# 1. How many neighborhood groups are there and which shows up the most?
# 2. Are private rooms the most popular in Manhattan?
# 3. Who are the top 10 busiest hosts based on number of reviews per month?
# 4. Which neighorhood group has the highest average price? Plot the average prices in a professional looking bar chart
# 5. What is the most expensive neighbourhood in each neighbourhood group?
# 6. Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
# 7. Who currently has no (zero) availability with a review count of 100 or more?
# 8. If each host rents all of their properties for the night, which 5 make the most that night?
# 9. When did Danielle from Queens last receive a review?
# 10. Display a bar chart showing the number of each type of room in the Bronx
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this entire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to simulate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighbourhood groups / which shows up the most
air_bnb['neighbourhood_group'].describe()
# Out:
# count         48895
# unique            5
# top       Manhattan
# freq          21661
# Name: neighbourhood_group, dtype: object

# %%
# Are private rooms the most popular in Manhattan?
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Who are the top 10 busiest hosts based on number of reviews per month?
busy_host = air_bnb.groupby(['host_id','host_name']).sum()
busy_host.sort_values('reviews_per_month', ascending=False)[['reviews_per_month']].head(10)
# Out:
#                                           reviews_per_month
# host_id   host_name
# 219517861 Sonder (NYC)                               397.56
# 244361589 Row NYC                                    111.72
# 232251881 Lakshmee                                    80.63
# 26432133  Danielle                                    68.02
# 137274917 David                                       62.89
# 224414117 Gabriel                                     59.10
# 156948703 Asad                                        56.44
# 344035    Brooklyn&   Breakfast    -Len-              56.00
# 156684502 Nalicia                                     54.38
# 37312959  Maya                                        53.53

# %%
# Which neighborhood group has the highest avg price and plot the average prices in a bar chart

# %%
# What is the most expensive neighbourhood in each neighbourhood_group
exp = air_bnb.groupby(['neighbourhood_group', 'neighbourhood'])['price'].describe()
exp.sort_values(['neighbourhood_group','mean'], ascending=False)
# Out:
#                                     count        mean          std    min  \
# neighbourhood_group neighbourhood
# Staten Island       Fort Wadsworth    1.0  800.000000          NaN  800.0
#                     Woodrow           1.0  700.000000          NaN  700.0
#                     Prince's Bay      4.0  409.500000   561.875728   85.0
#                     Randall Manor    19.0  336.000000  1130.121282   13.0
#                     Willowbrook       1.0  249.000000          NaN  249.0
# ...                                   ...         ...          ...    ...
# Bronx               Mount Eden        6.0   58.500000    46.194155   25.0
#                     Bronxdale        19.0   57.105263    20.283805   25.0
#                     Soundview        15.0   53.466667    19.115688   28.0
#                     Tremont          11.0   51.545455    34.468431   25.0
#                     Hunts Point      18.0   50.500000    27.181849   35.0
#
# ...

# %%
# Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
air_bnb['min_price'] =air_bnb['minimum_nights'] * air_bnb['price']
air_bnb[['host_name', 'min_price']].sort_values('min_price', ascending=False)
# Out:
#           host_name  min_price
# 48043         Jenny    1170000
# 9151       Kathrine    1000000
# 12342           Amy     989901
# 17811         Iveta     857750
# 44429        Noelle     730000
# ...             ...        ...
# 23161      Kimberly          0
# 25794       Adeyemi          0
# 26841        Sergii          0
# 26866        Sergii          0
# 25634  Martial Loft          0
#
# [48895 rows x 2 columns]

# %%
# Who has no (zero) availability with a review count of 100 or more
air_bnb[(air_bnb['availability_365'] == 0) & (air_bnb['number_of_reviews'] >= 100)][['host_name', 'number_of_reviews', 'availability_365']]
# Out:
#         host_name  number_of_reviews  availability_365
# 8       MaryEllen                118                 0
# 94     Christiana                168                 0
# 132           Sol                193                 0
# 174         Coral                114                 0
# 180          Doug                206                 0
# ...           ...                ...               ...
# 29581    Kathleen                103                 0
# 30461       Janet                119                 0
# 31250      Albert                102                 0
# 32670    Stephany                131                 0
# 35014     Mariluz                112                 0
#
# [162 rows x 3 columns]

# %%
# If each host rents all of their properties for the night, which 5 make the most that night?
one_night_max = air_bnb.groupby(['host_id', 'host_name']).sum()
one_night_max.sort_values('price', ascending=False).head(5)
# Out:
#                                  id     latitude    longitude  price  \
# host_id   host_name
# 219517861 Sonder (NYC)  10885561678  13316.25823 -24198.18856  82795
# 107434423 Blueground     7210036953   9451.60418 -17166.13165  70331
# 156158778 Sally           332529233    488.73929   -887.71735  37097
# 205031545 Red Awning     1415225676   1996.92821  -3624.34656  35294
# 30283594  Kara           1611854192   4931.41347  -8952.50779  33581
#
#                         minimum_nights  number_of_reviews  reviews_per_month  \
# host_id   host_name
# 219517861 Sonder (NYC)            4353               1281             397.56
# 107434423 Blueground              7470                 29               6.04
# 156158778 Sally                     12                  1               1.00
# 205031545 Red Awning               750                127              21.21
# 30283594  Kara                    3767                 65               3.94
#
# ...

# %%
# When did Danielle from Queens last receive a review?
air_bnb[air_bnb['host_name'] == 'Danielle'][['host_name', 'last_review']].sort_values('last_review', ascending=False).head(5)
# Out:
#       host_name last_review
# 22469  Danielle  2019-07-08
# 21517  Danielle  2019-07-07
# 20403  Danielle  2019-07-06
# 5717   Danielle  2019-07-06
# 29546  Danielle  2019-07-06

# %%
# bar chart showing the number of room types in the Bronx
rooms = air_bnb.groupby(['room_type'])
private_rooms = rooms.get_group('Private room').count()['calculated_host_listings_count']
entire_home = rooms.get_group('Entire home/apt').count()['calculated_host_listings_count']
shared_room = rooms.get_group('Shared room').count()['calculated_host_listings_count']
plt.bar(
    air_bnb['room_type'].unique(), 
    [private_rooms, entire_home, shared_room], 
    color='g',
    ec='black',
)
plt.ylabel('calculated host listings count', color='white')
plt.xlabel('room types', color='white')
plt.title('Room Type Count', color='white')
# Out:
# Text(0.5, 1.0, 'Room Type Count')

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %%
It is clear that Manhattan was the neighborhood with the most listings from the five different neighbors, and the listing with an entire property was the most popular listing in Manhattan. Needless to say, Sonder (NYC) and Row (NYC) have a significant jump based on the reviews per month.
Comparing Manhattan to the other four regions, there is also a notable increase in average listing prices.Compared to Queens and Bronx, prices in Manhattan are nearly twice as high. Interestingly, Staten Island has the most expensive listings, despite the average price in Manhattan being twice as high.
Also, Jenny has the highest minimum price because she requires the most minimum nights compared to the other listings.Using the data, we see that there are 162 hosts with over 100 reviews that are not available.It is not surprising that Sonder NYC would profit most from the rental of all the properties for one night.
According to the room type counts, the number of shared rooms seems to be decreasing while the number of entire homes/apartments are increasing.
